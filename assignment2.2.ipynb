# %%
import re
import pandas as pd
import numpy as np
from plotnine import *
from mizani.formatters import percent_format
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from py_helper_functions import *
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data Prepare

# %%
data = pd.read_csv('listings.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18288 entries, 0 to 18287
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            18288 non-null  int64
#  1   listing_url                                   18288 non-null  object
#  2   scrape_id                                     18288 non-null  int64
#  3   last_scraped                                  18288 non-null  object
#  4   name                                          18259 non-null  object
#  5   description                                   17744 non-null  object
#  6   neighborhood_overview                         9585 non-null   object
#  7   picture_url                                   18288 non-null  object
#  8   host_id                                       18288 non-null  int64
#  9   host_url                                      18288 non-null  object
#  10  host_name                                     18272 non-null  object
#  11  host_since                                    18272 non-null  object
#  12  host_location                                 18229 non-null  object
#  13  host_about                                    8985 non-null   object
#  14  host_response_time                            8412 non-null   object
#  15  host_response_rate                            8412 non-null   object
#  16  host_acceptance_rate                          9098 non-null   object
#  17  host_is_superhost                             18272 non-null  object
#  18  host_thumbnail_url                            18272 non-null  object
#  19  host_picture_url                              18272 non-null  object
#  20  host_neighbourhood                            12197 non-null  object
#  21  host_listings_count                           18272 non-null  float64
#  22  host_total_listings_count                     18272 non-null  float64
#  23  host_verifications                            18288 non-null  object
#  24  host_has_profile_pic                          18272 non-null  object
#  25  host_identity_verified                        18272 non-null  object
#  26  neighbourhood                                 9586 non-null   object
#  27  neighbourhood_cleansed                        18288 non-null  object
#  28  neighbourhood_group_cleansed                  18288 non-null  object
#  29  latitude                                      18288 non-null  float64
#  30  longitude                                     18288 non-null  float64
#  31  property_type                                 18288 non-null  object
#  32  room_type                                     18288 non-null  object
#  33  accommodates                                  18288 non-null  int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                18262 non-null  object
#  36  bedrooms                                      16679 non-null  float64
#  37  beds                                          18061 non-null  float64
#  38  amenities                                     18288 non-null  object
#  39  price                                         18288 non-null  object
#  40  minimum_nights                                18288 non-null  int64
#  41  maximum_nights                                18288 non-null  int64
#  42  minimum_minimum_nights                        18287 non-null  float64
#  43  maximum_minimum_nights                        18287 non-null  float64
#  44  minimum_maximum_nights                        18287 non-null  float64
#  45  maximum_maximum_nights                        18287 non-null  float64
#  46  minimum_nights_avg_ntm                        18287 non-null  float64
#  47  maximum_nights_avg_ntm                        18287 non-null  float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              18288 non-null  object
#  50  availability_30                               18288 non-null  int64
#  51  availability_60                               18288 non-null  int64
#  52  availability_90                               18288 non-null  int64
#  53  availability_365                              18288 non-null  int64
#  54  calendar_last_scraped                         18288 non-null  object
#  55  number_of_reviews                             18288 non-null  int64
#  56  number_of_reviews_ltm                         18288 non-null  int64
#  57  number_of_reviews_l30d                        18288 non-null  int64
#  58  first_review                                  14716 non-null  object
#  59  last_review                                   14716 non-null  object
#  60  review_scores_rating                          14716 non-null  float64
#  61  review_scores_accuracy                        14391 non-null  float64
#  62  review_scores_cleanliness                     14393 non-null  float64
#  63  review_scores_checkin                         14379 non-null  float64
#  64  review_scores_communication                   14390 non-null  float64
#  65  review_scores_location                        14380 non-null  float64
#  66  review_scores_value                           14378 non-null  float64
#  67  license                                       2269 non-null   object
#  68  instant_bookable                              18288 non-null  object
#  69  calculated_host_listings_count                18288 non-null  int64
#  70  calculated_host_listings_count_entire_homes   18288 non-null  int64
#  71  calculated_host_listings_count_private_rooms  18288 non-null  int64
#  72  calculated_host_listings_count_shared_rooms   18288 non-null  int64
#  73  reviews_per_month                             14716 non-null  float64
# dtypes: float64(22), int64(17), object(35)
# memory usage: 10.3+ MB

# %%
data.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   2015   https://www.airbnb.com/rooms/2015  20210921151214   2021-09-22
# 1   3176   https://www.airbnb.com/rooms/3176  20210921151214   2021-09-22
# 2   7071   https://www.airbnb.com/rooms/7071  20210921151214   2021-09-22
# 3   9991   https://www.airbnb.com/rooms/9991  20210921151214   2021-09-22
# 4  14325  https://www.airbnb.com/rooms/14325  20210921151214   2021-09-22
#
#                                                name  \
# 0  Berlin-Mitte Value! Quiet courtyard/very central
# 1                   Fabulous Flat in great Location
# 2                  BrightRoom with sunny greenview!
# 3               Geourgeous flat - outstanding views
# 4                      Apartment in Prenzlauer Berg
#
#                                          description  \
# 0  Great location!  <br />30 of 75 sq meters. Thi...
# 1  This beautiful first floor apartment  is situa...
# 2  Cozy and large room in the beautiful district ...
# 3  4 bedroom with very large windows and outstand...
# 4  The apartment is located on the upper second f...
#
#                                neighborhood_overview  \
# 0  It is located in the former East Berlin area o...
# 1  The neighbourhood is famous for its variety of...
# 2  Great neighborhood with plenty of Cafés, Baker...
# 3  Prenzlauer Berg is an amazing neighbourhood wh...
# 4                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/260fd609-710a...     2217
# 1  https://a0.muscache.com/pictures/243355/84afcf...     3718
# 2  https://a0.muscache.com/pictures/21278/32a1622...    17391
# 3  https://a0.muscache.com/pictures/42799131/59c8...    33852
# 4  https://a0.muscache.com/pictures/508703/24988a...    55531
#
#                                   host_url  ... review_scores_communication  \
# 0   https://www.airbnb.com/users/show/2217  ...                        4.89
# 1   https://www.airbnb.com/users/show/3718  ...                        4.69
# 2  https://www.airbnb.com/users/show/17391  ...                        4.85
# 3  https://www.airbnb.com/users/show/33852  ...                        5.00
# 4  https://www.airbnb.com/users/show/55531  ...                        4.84
#
#   review_scores_location review_scores_value            license  \
# 0                   4.96                4.59                NaN
# 1                   4.92                4.63                NaN
# 2                   4.91                4.71                NaN
# 3                   4.86                4.86  03/Z/RA/003410-18
# 4                   4.58                4.42                NaN
#
#   instant_bookable calculated_host_listings_count  \
# 0                f                              5
# 1                f                              1
# 2                t                              1
# 3                f                              1
# 4                f                              3
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           5
# 1                                           1
# 2                                           0
# 3                                           1
# 4                                           3
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            1
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              2.15
# 1                                           0              1.12
# 2                                           0              2.40
# 3                                           0              0.16
# 4                                           0              0.26
#
# [5 rows x 74 columns]

# %%
len(data)  # the total number of Berlin airbnb data
# Out:
# 18288

# %%
# Size, we need a normal apartment, 2-6persons according to assignment
data=data.loc[(data.accommodates < 7) & (data.accommodates > 1)]

# %%
len(data)  # after selecting
# Out:
# 15611

# %%
# show the columns of missing value
na_filter=data.isna().sum()
na_filter[na_filter > 0].index
# Out:
# Index(['name', 'description', 'neighborhood_overview', 'host_name',
#        'host_since', 'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'bathrooms', 'bathrooms_text', 'bedrooms', 'beds', 'calendar_updated',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'license',
#        'reviews_per_month'],
#       dtype='object')

# %%
# process the missing value
# fill median strategy with these attributes:
data['host_listings_count']=data['host_listings_count'].fillna(np.nanmedian(data['host_listings_count']))
data['host_total_listings_count']=data['host_total_listings_count'].fillna(np.nanmedian(data['host_total_listings_count']))
data['bedrooms']=data['bedrooms'].fillna(np.nanmedian(data['bedrooms']))
data['beds']=data['beds'].fillna(np.nanmedian(data['beds']))

# drop these attributes: Because there are too many missing
data.drop(columns=['bathrooms', 'calendar_updated', 'license', 'neighbourhood',
                  'neighborhood_overview', 'host_about', 'host_response_time',
                  'host_response_rate', 'host_acceptance_rate', 'host_neighbourhood'], inplace=True)

# drop rows if no value on these attributes
data.dropna(subset=['review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness',
                    'review_scores_checkin', 'review_scores_communication', 'review_scores_location',
                    'review_scores_value', 'reviews_per_month', 'bathrooms_text'], inplace=True)

# %%
# Because the missing number of these attributes is small, they are assigned randomly
data['host_is_superhost']=data['host_is_superhost'].fillna('t')
data['host_has_profile_pic']=data['host_has_profile_pic'].fillna('t')
data['host_identity_verified']=data['host_identity_verified'].fillna('t')

# %%
# object to numerical type
data['host_is_superhost']=(data['host_is_superhost']=='t').astype(int)
data['host_has_profile_pic']=(data['host_has_profile_pic']=='t').astype(int)
data['host_identity_verified']=(data['host_identity_verified']=='t').astype(int)
data['has_availability']=(data['has_availability']=='t').astype(int)
data['instant_bookable']=(data['instant_bookable']=='t').astype(int)

# %%
data.property_type.value_counts()
# Out:
# Entire rental unit                     6546
# Private room in rental unit            4050
# Entire condominium (condo)              352
# Entire loft                             275
# Entire serviced apartment               230
# Private room in residential home        137
# Private room in condominium (condo)     127
# Room in hotel                            89
# Entire residential home                  85
# Private room in loft                     52
# Entire guesthouse                        50
# Room in boutique hotel                   46
# Shared room in hostel                    40
# Private room in townhouse                39
# Private room in bed and breakfast        36
# Shared room in rental unit               33
# Room in serviced apartment               30
# Room in aparthotel                       28
# Private room in hostel                   28
# Entire guest suite                       25
# Entire bungalow                          20
# Private room in serviced apartment       16
# Houseboat                                15
# Private room                             13
# Entire townhouse                         10
# Tiny house                                8
# Private room in guesthouse                7
# Private room in guest suite               7
# Private room in pension                   7
# Entire villa                              5
# Room in hostel                            5
# Camper/RV                                 5
# Entire place                              5
# Private room in boat                      4
# Entire cottage                            4
# Entire cabin                              4
# Shared room in boutique hotel             4
# Private room in tiny house                3
# Private room in cottage                   2
# Private room in casa particular           2
# Shared room in condominium (condo)        2
# Treehouse                                 2
# Private room in villa                     2
# Boat                                      2
# Room in bed and breakfast                 2
# Private room in bungalow                  1
# Shared room in boat                       1
# Private room in tipi                      1
# Casa particular                           1
# Private room in floor                     1
# Earth house                               1
# Island                                    1
# Shared room in residential home           1
# Private room in cave                      1
# Entire chalet                             1
# Shared room in tiny house                 1
# Shared room in townhouse                  1
# Private room in houseboat                 1
# Name: property_type, dtype: int64

# %%
# Rename roomt type because it is too long, just two classes
data= data.loc[data.property_type.isin(['Entire rental unit', 'Private room in rental unit'])]

# %%
data.property_type = ['entire uint' if x == 'Entire rental unit' else 'private room' for x in data.property_type]
data['f_property_type'] = data['property_type'].astype('category')

# %%
data.room_type.value_counts()
# Out:
# Entire home/apt    6546
# Private room       4050
# Name: room_type, dtype: int64

# %%
data['f_room_type'] = data['room_type'].astype('category')
data["f_room_type2"] = (
    data["f_room_type"]
    .replace(
        {
            "Entire home/apt": "Entire/Apt",
            "Private room": "Private",
        }
    )
    .astype("category")
)

# %%
# process bathrooms_text to get bathrooms
def process_bathText(text, n_persons):
    texts = text.split(' ')
    if texts[0].isdigit() or (texts[0].split('.')[0].isdigit() and texts[0].split('.')[1].isdigit()):
        if texts[1] == 'shared':
            return float(texts[0]) / n_persons
        else:
            return float(texts[0])
    else:
        if texts[0] in ['Half-bath', 'Private']:
            return 0.5
        if texts[0] == 'Shared':
            return 0.5 / n_persons

# %%
data['bathrooms']=data.apply(lambda row: process_bathText(row['bathrooms_text'], 
                                                          row['accommodates']), axis=1)

# %%
data['f_neighbourhood_cleansed'] = data['neighbourhood_cleansed'].astype('category')
data['f_neighbourhood_group_cleansed'] = data['neighbourhood_group_cleansed'].astype('category')

# %%
data['n_days_since'] = pd.to_datetime(
    data['calendar_last_scraped'], format='%Y-%m-%d'
) - pd.to_datetime(data["first_review"], format="%Y-%m-%d")
# Previous row creates a timedelta object in each row. Get the elapsed number of days like:
data['n_days_since'] = [x.days for x in data['n_days_since']]

# %%
# process amenities
amenities = data['amenities'].values
total_map = {}  # all kinds of amenities, hash map
for item in amenities:
    for i in eval(item):
        if i not in total_map.keys():
            total_map[i] = 1
        else:
            total_map[i] += 1

# select top 50 frequency amenities
top50_amenities = sorted(total_map.items(), key=lambda x:-x[1])[:50]
top50_amenities = [x[0] for x in top50_amenities]
# add attributes
for col in top50_amenities:
    data['d_' + col] = 0

# %%
# process the column amenities
def processAmenities(items, amenity):
    for item in items:
        if item == amenity:
            return 1
    return 0

        
for col in top50_amenities:
    data['d_' + col] = data.apply(lambda row: processAmenities(eval(row['amenities']), col), axis=1)

# %%
for column in (
    'accommodates',
    'bathrooms',
    'review_scores_rating',
    'number_of_reviews',
    'reviews_per_month',
    'minimum_nights',
    'beds',
):
    data["n_" + re.sub(r"[^[:alnum:]_]", "", column.lower())] = data[column].astype(
        "float"
    )

# %%
amenities=list(data.filter(regex='^d_.*'))
len(amenities)
# Out:
# 50

# %%
data.filter(regex=('^d_.*|^n_.*|^f_.*')).columns
# Out:
# Index(['f_property_type', 'f_room_type', 'f_room_type2',
#        'f_neighbourhood_cleansed', 'f_neighbourhood_group_cleansed',
#        'n_days_since', 'd_Kitchen', 'd_Wifi', 'd_Essentials', 'd_Heating',
#        'd_Washer', 'd_Long term stays allowed', 'd_Hair dryer', 'd_Hangers',
#        'd_Dedicated workspace', 'd_Hot water', 'd_Iron',
#        'd_Dishes and silverware', 'd_Cooking basics', 'd_Smoke alarm',
#        'd_Shampoo', 'd_Refrigerator', 'd_Stove', 'd_Oven', 'd_Bed linens',
#        'd_Coffee maker', 'd_TV', 'd_Free street parking', 'd_Dishwasher',
#        'd_Host greets you', 'd_Patio or balcony', 'd_Microwave', 'd_Elevator',
#        'd_Extra pillows and blankets', 'd_First aid kit', 'd_Private entrance',
#        'd_Luggage dropoff allowed', 'd_Carbon monoxide alarm', 'd_Cable TV',
#        'd_TV with standard cable', 'd_Bathtub', 'd_Dryer',
#        'd_Fire extinguisher', 'd_Lock on bedroom door', 'd_Baking sheet',
#        'd_Free parking on premises', 'd_Room-darkening shades',
#        'd_Single level home', 'd_Shower gel', 'd_Paid parking off premises',
#        'd_Hot water kettle', 'd_Freezer', 'd_Backyard', 'd_Cleaning products',
#        'd_Dining table', 'd_High chair', 'n_accommodates', 'n_bathrooms',
#        'n_review_scores_rating', 'n_number_of_reviews', 'n_reviews_per_month',
#        'n_minimum_nights', 'n_beds'],
#       dtype='object')

# %%
# keep columns if contain d_, n_,f_, p_, usd_ and some others
data = data.filter(regex=('^d_.*|^n_.*|^f_.*')).join(
    data[
        [
            'price',
            'id',
            'neighbourhood_cleansed',
            'room_type',
            'property_type',
        ]
    ]
)

# %%
# deal price
data['price']=data['price'].str[1:]  # delete $
data['price']=data['price'].str.replace(",","").astype('float')

# %%
data.price.describe()
# Out:
# count    10596.000000
# mean        67.423179
# std         67.759774
# min          8.000000
# 25%         39.000000
# 50%         55.000000
# 75%         80.000000
# max       3455.000000
# Name: price, dtype: float64

# %%
data['ln_price']=np.log(data.price)

# %%
# Remove extreme values from prices
data=data.loc[data.price <400]

# %%
# Histograms
(
    ggplot(data, aes('price'))
    + geom_histogram(
        binwidth=25, fill=color[0], color='white', alpha=0.8, size=0.25, closed='left'
    )
    + ylab('Count')
    + xlab('Price')
    + theme_bw()
)
# Out:
# <ggplot: (8775006464597)>

# %%
(
    ggplot(data, aes('ln_price'))
    + geom_histogram(
        binwidth=0.15, fill=color[0], color='white', alpha=0.8, size=0.25, closed='left'
    )
    + ylab('Count')
    + xlab('Log price')
    + theme_bw()
)
# Out:
# <ggplot: (8774988688933)>

# %%
(
    ggplot(data, aes(x='n_accommodates', y='price'))
    + geom_point(size=1, colour=color[2])
    + ylim(0, 400)
    + xlim(1.7, 6.3)
    + labs(x='Number of people accomodated', y='Price')
    + geom_smooth(method='lm', colour=color[0], se=False)
    + theme_bw()
)
# Out:
# <ggplot: (8775007569369)>

# %%
data.groupby('n_accommodates').agg(mean_price=('price', np.mean))
# Out:
#                 mean_price
# n_accommodates
# 2.0              51.712230
# 3.0              65.236636
# 4.0              89.119913
# 5.0             111.515075
# 6.0             135.908397

# %%
## bathrooms
(
    ggplot(data, aes('n_bathrooms'))
    + geom_histogram(
        binwidth=0.5, closed='left', fill=color[0], color='white', alpha=0.8, size=0.25
    )
    + ylab('Count')
    + xlab('N of bathrooms')
    + theme_bw()
)
# Out:
# <ggplot: (8774971071237)>

# %%
# Pool accomodations with 0,1,[2~10) bathrooms
bins = pd.IntervalIndex.from_tuples([(0, 1), (1, 2), (2, 10)], closed='left')
f_bath = pd.cut(data['n_bathrooms'].to_list(), bins, labels=['0', '1', '2'])
f_bath.categories = [0, 1, 2]
data['f_bathroom'] = f_bath

# %%
data.groupby('f_bathroom').agg(mean_price=('price', np.mean), n=('price', 'size'))
# Out:
#             mean_price     n
# f_bathroom
# 0            39.615027  2795
# 1            71.936936  7421
# 2           132.310734   354

# %%
data.groupby('n_beds').agg(
    mean_price=('price', np.mean),
    min_price=('price', np.min),
    max_price=('price', np.max),
    n=('price', 'size'),
)
# Out:
#         mean_price  min_price  max_price     n
# n_beds
# 0.0      64.596306       16.0      277.0   379
# 1.0      53.140251       10.0      350.0  6139
# 2.0      73.506385        8.0      360.0  2741
# 3.0      98.515228       16.0      359.0   788
# 4.0     115.537791       23.0      390.0   344
# 5.0     116.352381       21.0      305.0   105
# 6.0     127.984848       24.0      392.0    66
# 7.0     155.857143       69.0      266.0     7
# 8.0      85.000000       85.0       85.0     1

# %%
(
    ggplot(data, aes(x='n_beds', y='price'))
    + geom_point(size=1, colour=color[2])
    + ylim(0, 400)
    + xlim(0, 8)
    + labs(x='N of beds', y='Price')
    + geom_smooth(method='lm', colour=color[0], se=False)
    + theme_bw()
)
# Out:
# <ggplot: (8774971217233)>

# %%
## Number of reviews
nreview_plot = data.loc[data.n_number_of_reviews <200]

# %%
(
    ggplot(nreview_plot, aes('n_number_of_reviews'))
    + geom_histogram(binwidth=5, fill=color[0], color='white', alpha=0.8, size=0.25)
    + ylab('Count')
    + xlab('N of reviews')
    + theme_bw()
)
# Out:
# <ggplot: (8775006891193)>

# %%
bins = pd.IntervalIndex.from_tuples([(0, 2), (2, 51), (51, max(data.n_number_of_reviews))], closed='left')
f_number_of_reviews = pd.cut(data['n_number_of_reviews'].to_list(), bins, labels=['0', '1', '2'])
f_number_of_reviews.categories = [0, 1, 2]
data['f_number_of_reviews'] = f_number_of_reviews

# %%
data.groupby('f_number_of_reviews').agg(median_price=('price', np.median), mean_price=('price', np.mean), n=('price', 'size'))
# Out:
#                      median_price  mean_price     n
# f_number_of_reviews
# 0                            50.0   59.757487  1369
# 1                            54.0   63.947526  7661
# 2                            65.0   77.755036  1539

# %%
# number of reviews: use logs as well
data['ln_number_of_reviews']=np.log(data.n_number_of_reviews+1)

# %%
(
    ggplot(data, aes('ln_number_of_reviews'))
    + geom_histogram(binwidth=0.5, fill=color[0], color="white", alpha=0.8, size=0.25)
    + ylab('Count')
    + xlab('Log N of reviews')
    + theme_bw()
)
# Out:
# <ggplot: (8774988628045)>

# %%
data['ln_days_since'] = np.log(data['n_days_since'])

# %%
(
    ggplot(data, aes(x='ln_days_since', y='ln_price'))
    + geom_point(size=1.5, colour=color[2])
    + ylim(2, 6)
    + xlim(0, 8.3)
    + geom_smooth(method='loess', colour=color[0], se=False)
    + labs(x='Log number of days since first review', y='Log daily price')
    + theme_bw()
)
# Out:
# <ggplot: (8774954925613)>

# %%
## review score effect
(
    ggplot(data, aes(x='n_review_scores_rating', y='price'))
    + geom_point(size=1.5, colour=color[2])
    + ylim(0, 400)
    + xlim(0, 5)
    + geom_smooth(method="loess", colour=color[0], se=False)
    + labs(x='Review score', y='Daily price (USD)')
    + theme_bw()
)
# Out:
# <ggplot: (8774955419213)>

# %% [markdown]
# ## Data Prediction

# %%
# where do we have missing variables now?
na_filter=data.isna().sum()
na_filter[na_filter>0].index
# Out:
# Index(['f_number_of_reviews'], dtype='object')

# %%
data['f_number_of_reviews']=data['f_number_of_reviews'].fillna(1)

# %%
data.groupby('f_property_type').agg(mean_price=('price', np.mean))
# Out:
#                  mean_price
# f_property_type
# entire uint       80.656145
# private room      40.812067

# %%
# Distribution of price by type below 400# Histograms# price
(
    ggplot(data, aes(x='price'))
    + geom_histogram(
        aes(y='stat(count)/sum(stat(count))'),
        binwidth=10,
        fill=color[0],
        color='white',
        alpha=0.8,
        boundary=0,
        closed='left',
    )
    + labs(x='Price (US dollars)', y='Percent')
    + scale_y_continuous(
        expand=(0.00, 0.00),
        limits=(0, 0.16),
        breaks=seq(0, 0.16, by=0.03),
        labels=percent_format(),
    )
    + scale_x_continuous(expand=(0.00, 0.00), limits=(0, 400), breaks=seq(0, 401, 50))
    + theme_bw()
)
# Out:
# <ggplot: (8774991772037)>

# %%
(
    ggplot(data, aes(x='ln_price'))
    + geom_histogram(
        aes(y='stat(count)/sum(stat(count))'),
        binwidth=0.2,
        fill=color[0],
        color='white',
        alpha=0.8,
        boundary=0,
        closed='left',
    )
    + coord_cartesian(xlim=(2.5, 6.5))
    + scale_y_continuous(
        expand=(0.00, 0.00),
        limits=(0, 0.16),
        breaks=seq(0, 0.16, by=0.05),
        labels=percent_format(),
    )
    + scale_x_continuous(expand=(0.00, 0.01), breaks=seq(2.4, 6.7, 0.6))
    + labs(x='ln(price, US dollars)', y='Percent')
    + theme_bw()
)
# Out:
# <ggplot: (8774971789797)>

# %%
## Boxplot of price by room type
(
    ggplot(data, aes(x='f_room_type', y='price'))
    + stat_boxplot(
        aes(group='f_room_type'),
        geom='errorbar',
        width=0.3,
        color=(color[1], color[0]),
        size=0.5,
        na_rm=True,
    )
    + geom_boxplot(
        aes(group='f_room_type'),
        color=(color[1], color[0]),
        size=0.5,
        width=0.6,
        alpha=0.3,
        na_rm=True,
        outlier_shape='',
    )
    + scale_y_continuous(expand=(0.01, 0.01), limits=(0, 160), breaks=seq(0, 201, 20))
    + labs(x='Room type', y='Price (US dollars)')
    + theme_bw()
)
# Out:
# <ggplot: (8774993179685)>

# %%
(
    ggplot(
        data,
        aes(
            x='factor(n_accommodates)',
            y='price',
            color='factor(f_property_type)',
        ),
    )
    + geom_boxplot(alpha=0.8, na_rm=True, outlier_shape='', width=0.8, stat='boxplot')
    + stat_boxplot(geom='errorbar', width=0.8, size=0.3, na_rm=True)
    + scale_color_manual(name='', values=(color[1], color[0]))
    + scale_fill_manual(name='', values=(color[1], color[0]))
    + labs(x='Accomodates (Persons)', y='Price (US dollars)')
    + scale_y_continuous(expand=(0.01, 0.01), limits=(0, 400), breaks=seq(0, 401, 50))
    + theme_bw()
    + theme(legend_position=(0.3, 0.8))
)
# Out:
# <ggplot: (8774993178833)>

# %%
## Helper functions
def price_diff_by_variables2(df, factor_var, dummy_var, factor_lab, dummy_lab):
    stats = df.groupby([factor_var, dummy_var]).agg(
        Mean=('price', np.mean), sd=('price', np.std), size=('price', 'size')
    )
    stats['se'] = stats['sd'] / stats['size'] ** (1 / 2)
    stats['Mean_l'] = stats['Mean'] - (1.96 * stats['se'])
    stats['Mean_u'] = stats['Mean'] + (1.96 * stats['se'])
    stats = stats.drop(['sd', 'size'], axis=1).reset_index()
    plot = (
        ggplot(
            stats,
            aes(
                stats.columns[0],
                stats.columns[2],
                fill='factor(' + stats.columns[1] + ')',
            ),
        )
        + geom_bar(stat='identity', position=position_dodge(width=0.9))
        + geom_errorbar(
            aes(ymin='Mean_l', ymax='Mean_u'),
            position=position_dodge(width=0.9),
            width=0.25,
        )
        + scale_color_manual(name=dummy_lab, values=(color[1], color[0]))
        + scale_fill_manual(name=dummy_lab, values=(color[1], color[0]))
        + ylab('Mean Price')
        + xlab(factor_lab)
        + theme_bw()
        + theme(
            panel_grid_major=element_blank(),
            panel_grid_minor=element_blank(),
            panel_border=element_blank(),
            axis_line=element_line(),
            legend_position='top',
            legend_box='vertical',
            legend_text=element_text(size=5),
            legend_title=element_text(size=5, face='bold'),
        )
    )

    return plot

# %%
price_diff_by_variables2(data,'f_room_type','d_TV','Room type', 'TV')
# Out:
# <ggplot: (8775007223309)>

# %%
price_diff_by_variables2(data,'f_room_type','d_Elevator','Room type', 'Elevator')
# Out:
# <ggplot: (8775007622741)>

# %%
# Barchart
(
    ggplot(
        data, aes(x='factor(n_accommodates)', color='f_room_type', fill='f_room_type')
    )
    + geom_bar(alpha=0.8, na_rm=True, width=0.8)
    + scale_color_manual(name='', values=(color[1], color[0], color[2]))
    + scale_fill_manual(name='', values=(color[1], color[0], color[2]))
    + labs(x='Accomodates (Persons)', y='Frequency')
    + theme_bw()
    + theme(legend_position='right')
)
# Out:
# <ggplot: (8774988529373)>

# %% [markdown]
# ## Model Selection

# %%
data.drop(columns=['neighbourhood_cleansed', 'room_type', 'property_type', 'f_property_type',
                  'f_room_type2', 'f_neighbourhood_cleansed', 'f_neighbourhood_group_cleansed',
                  'ln_price', 'id', 'f_bathroom'], axis=1, inplace=True)

# %%
data['f_room_type'] = (data['f_room_type'] == 'Entire home/apt').astype(int)

# %%
X = data.drop(['price'], axis=1)  # X
y = data['price']  # target
# data standard
ss = StandardScaler()
X_std = ss.fit_transform(X)

# train test split
X_train, X_test, y_train, y_test = train_test_split(X_std, y, test_size=0.2, random_state=42)

# %% [markdown]
# ### ols model

# %%
ols_model = LinearRegression().fit(X_train, y_train)
y_hat = ols_model.predict(X_test)
ols_rmse = mean_squared_error(y_test, y_hat, squared=False)

# %%
ols_model_coeffs_df = pd.DataFrame(
    ols_model.coef_.tolist(),
    index=X.columns,
    columns=['ols_coefficient'],
).assign(ols_coefficient=lambda x: x.ols_coefficient.round(3))
ols_model_coeffs_df.sort_values('ols_coefficient', inplace=True, ascending=False)

# %%
ols_model_coeffs_df.plot.bar(y='ols_coefficient', rot=90, figsize=(15, 5), title='OLS Model Coeffs')
# Out:
# <AxesSubplot:title={'center':'OLS Model Coeffs'}>

# %%
for index in ols_model_coeffs_df.index:
    print(index, ols_model_coeffs_df.loc[index].values[0])
# Out:
# n_accommodates 11.945
# n_bathrooms 7.853
# f_room_type 7.312
# ln_number_of_reviews 6.153
# d_Dishwasher 3.511
# d_Elevator 3.058
# d_Coffee maker 2.463
# d_Dryer 2.319
# n_beds 2.282
# d_Cable TV 2.111
# d_Paid parking off premises 1.822
# d_TV 1.8
# d_Fire extinguisher 1.57
# d_High chair 1.569
# n_review_scores_rating 1.264
# d_Oven 1.155
# d_Hair dryer 1.019
# d_Iron 0.976
# d_Shampoo 0.958
# d_Hot water 0.828
# d_Patio or balcony 0.81
# d_Carbon monoxide alarm 0.708
# d_Bed linens 0.651
# d_Shower gel 0.587
# d_Wifi 0.513
# d_Private entrance 0.497
# d_Dining table 0.495
# d_Hot water kettle 0.44
# d_Long term stays allowed 0.419
# d_TV with standard cable 0.379
# d_Hangers 0.245
# d_Dishes and silverware 0.134
# d_Dedicated workspace 0.115
# d_Essentials 0.045
# d_Bathtub 0.031
# d_Lock on bedroom door -0.138
# d_Single level home -0.163
# d_Smoke alarm -0.164
# d_Freezer -0.234
# d_Backyard -0.279
# d_Baking sheet -0.329
# d_Kitchen -0.39
# d_Washer -0.397
# d_Cleaning products -0.399
# d_Cooking basics -0.404
# d_First aid kit -0.426
# n_reviews_per_month -0.451
# d_Luggage dropoff allowed -0.455
# d_Room-darkening shades -0.513
# d_Free parking on premises -0.564
# d_Host greets you -0.774
# d_Refrigerator -0.869
# d_Heating -0.929
# d_Stove -1.186
# f_number_of_reviews -1.562
# d_Extra pillows and blankets -1.699
# ln_days_since -1.851
# n_number_of_reviews -1.956
# n_minimum_nights -2.059
# n_days_since -2.064
# d_Microwave -2.217
# d_Free street parking -2.54

# %%
ols_model_coeffs_var_imp_df = (
    pd.DataFrame(
        abs(ols_model.coef_), X.columns
    )
    .reset_index()
    .rename({'index': 'varname',0: 'imp'}, axis=1)
    .assign(imp_percentage=lambda x: x['imp'] / x['imp'].sum())
    .sort_values(by=['imp'], ascending=False)
)

# %%
ggplot(
    ols_model_coeffs_var_imp_df.iloc[:10, :],
    aes(x='reorder(varname, imp)', y='imp_percentage'),
) + geom_point(color=color[0], size=1.5) + geom_segment(
    aes(x='varname', xend='varname', y=0, yend='imp_percentage'), color=color[0], size=1
) + ylab(
    'Importance (Percent)'
) + xlab(
    'OLS Model Variable Name'
) + coord_flip() + scale_y_continuous(
    labels=percent_format()
) + theme_bw()
# Out:
# <ggplot: (8774993724789)>

# %%
# cross validation
ols_model = LinearRegression()
ols_cv_mse = cross_val_score(ols_model, X_std, y, cv=5, scoring='neg_mean_squared_error')
ols_cv_rmse = [np.sqrt(-x) for x in ols_cv_mse]

# %%
ols_cv_rmse
# Out:
# [29.29636789040002,
#  32.51810116655386,
#  29.424639590941045,
#  31.28375267771522,
#  31.205196342391513]

# %% [markdown]
# ### lasso model

# %%
lasso_model = Lasso(alpha=0.5).fit(X_train, y_train)
y_hat = lasso_model.predict(X_test)
lasso_rmse = mean_squared_error(y_test, y_hat, squared=False)

# %%
lasso_model_coeffs_df = pd.DataFrame(
    lasso_model.coef_.tolist(),
    index=X.columns,
    columns=['lasso_coefficient'],
).assign(lasso_coefficient=lambda x: x.lasso_coefficient.round(3))
lasso_model_coeffs_df.sort_values('lasso_coefficient', inplace=True, ascending=False)

# %%
lasso_model_coeffs_df.plot.bar(y='lasso_coefficient', rot=90, figsize=(15, 5), title='lasso Model Coeffs')
# Out:
# <AxesSubplot:title={'center':'lasso Model Coeffs'}>

# %%
for index in lasso_model_coeffs_df.index:
    print(index, lasso_model_coeffs_df.loc[index].values[0])
# Out:
# n_accommodates 11.989
# n_bathrooms 7.872
# f_room_type 7.499
# d_Dishwasher 3.09
# d_Elevator 2.784
# ln_number_of_reviews 2.373
# n_beds 1.914
# d_Dryer 1.903
# d_Coffee maker 1.835
# d_Cable TV 1.803
# d_Paid parking off premises 1.541
# d_High chair 1.261
# d_TV 1.205
# d_Fire extinguisher 1.158
# d_Hair dryer 0.91
# n_review_scores_rating 0.83
# d_Iron 0.758
# d_Shampoo 0.626
# d_Patio or balcony 0.428
# d_Carbon monoxide alarm 0.282
# d_Hot water 0.281
# d_Private entrance 0.232
# d_Long term stays allowed 0.03
# d_Baking sheet 0.0
# d_Shower gel 0.0
# d_Hangers 0.0
# d_Hot water kettle 0.0
# d_Freezer 0.0
# d_Backyard -0.0
# d_Cleaning products 0.0
# d_Dining table 0.0
# d_Bed linens 0.0
# d_Washer -0.0
# d_Essentials 0.0
# n_number_of_reviews -0.0
# n_reviews_per_month 0.0
# d_Wifi 0.0
# f_number_of_reviews -0.0
# d_Kitchen -0.0
# d_Single level home -0.0
# d_Room-darkening shades -0.0
# d_Stove -0.0
# d_Lock on bedroom door -0.0
# d_Dedicated workspace 0.0
# d_Dishes and silverware 0.0
# d_Bathtub 0.0
# d_TV with standard cable 0.0
# d_Cooking basics 0.0
# d_Smoke alarm 0.0
# d_Luggage dropoff allowed -0.0
# d_Oven 0.0
# d_First aid kit -0.0
# d_Refrigerator -0.0
# d_Free parking on premises -0.069
# d_Host greets you -0.096
# d_Heating -0.235
# d_Extra pillows and blankets -0.647
# ln_days_since -1.01
# d_Microwave -1.277
# n_minimum_nights -1.424
# d_Free street parking -2.091
# n_days_since -2.225

# %%
lasso_model_coeffs_var_imp_df = (
    pd.DataFrame(
        abs(lasso_model.coef_), X.columns
    )
    .reset_index()
    .rename({'index': 'varname',0: 'imp'}, axis=1)
    .assign(imp_percentage=lambda x: x['imp'] / x['imp'].sum())
    .sort_values(by=['imp'], ascending=False)
)

# %%
ggplot(
    lasso_model_coeffs_var_imp_df.iloc[:10, :],
    aes(x='reorder(varname, imp)', y='imp_percentage'),
) + geom_point(color=color[0], size=1.5) + geom_segment(
    aes(x='varname', xend='varname', y=0, yend='imp_percentage'), color=color[0], size=1
) + ylab(
    'Importance (Percent)'
) + xlab(
    'lasso Model Variable Name'
) + coord_flip() + scale_y_continuous(
    labels=percent_format()
) + theme_bw()
# Out:
# <ggplot: (8773117154165)>

# %%
# cross validation
lasso_model = Lasso(alpha=0.5)
lasso_cv_mse = cross_val_score(lasso_model, X_std, y, cv=5, scoring='neg_mean_squared_error')
lasso_cv_rmse = [np.sqrt(-x) for x in lasso_cv_mse]

# %%
lasso_cv_rmse
# Out:
# [29.038322264028157,
#  32.84100143202453,
#  29.47378952373234,
#  31.27483214369647,
#  30.921388858971127]

# %% [markdown]
# ### CART Model

# %%
cart_model = DecisionTreeRegressor().fit(X_train, y_train)
y_hat = cart_model.predict(X_test)
cart_rmse = mean_squared_error(y_test, y_hat, squared=False)

# %%
cart_model_coeffs_df = pd.DataFrame(
    cart_model.feature_importances_.tolist(),
    index=X.columns,
    columns=['cart_coefficient'],
).assign(cart_coefficient=lambda x: x.cart_coefficient.round(3))
cart_model_coeffs_df.sort_values('cart_coefficient', inplace=True, ascending=False)

# %%
cart_model_coeffs_df.plot.bar(y='cart_coefficient', rot=90, figsize=(15, 5), title='cart Model Coeffs')
# Out:
# <AxesSubplot:title={'center':'cart Model Coeffs'}>

# %%
for index in cart_model_coeffs_df.index:
    print(index, cart_model_coeffs_df.loc[index].values[0])
# Out:
# n_accommodates 0.255
# f_room_type 0.098
# n_bathrooms 0.083
# n_reviews_per_month 0.063
# n_minimum_nights 0.04
# n_review_scores_rating 0.038
# n_days_since 0.036
# n_number_of_reviews 0.036
# ln_days_since 0.03
# d_Dishwasher 0.022
# ln_number_of_reviews 0.02
# n_beds 0.02
# d_Shampoo 0.015
# d_Paid parking off premises 0.014
# d_Elevator 0.013
# d_Free street parking 0.011
# d_Host greets you 0.011
# d_Dryer 0.009
# d_Carbon monoxide alarm 0.008
# d_Hair dryer 0.008
# d_Fire extinguisher 0.008
# d_Luggage dropoff allowed 0.007
# d_Private entrance 0.007
# d_Dedicated workspace 0.007
# d_Heating 0.007
# d_Iron 0.007
# d_TV 0.006
# d_Shower gel 0.006
# d_Microwave 0.006
# d_Hot water 0.006
# d_Free parking on premises 0.006
# d_Baking sheet 0.005
# d_Long term stays allowed 0.005
# d_Wifi 0.005
# d_Hangers 0.005
# d_Patio or balcony 0.005
# d_First aid kit 0.004
# d_Coffee maker 0.004
# d_Bed linens 0.004
# d_Oven 0.004
# d_High chair 0.004
# d_Cable TV 0.003
# d_Dining table 0.003
# f_number_of_reviews 0.003
# d_Kitchen 0.003
# d_Smoke alarm 0.003
# d_Refrigerator 0.003
# d_Washer 0.003
# d_TV with standard cable 0.003
# d_Bathtub 0.003
# d_Cleaning products 0.002
# d_Freezer 0.002
# d_Stove 0.002
# d_Hot water kettle 0.002
# d_Room-darkening shades 0.002
# d_Cooking basics 0.002
# d_Extra pillows and blankets 0.002
# d_Dishes and silverware 0.002
# d_Backyard 0.002
# d_Single level home 0.001
# d_Essentials 0.001
# d_Lock on bedroom door 0.001

# %%
cart_model_coeffs_var_imp_df = (
    pd.DataFrame(
        abs(cart_model.feature_importances_), X.columns
    )
    .reset_index()
    .rename({'index': 'varname',0: 'imp'}, axis=1)
    .assign(imp_percentage=lambda x: x['imp'] / x['imp'].sum())
    .sort_values(by=['imp'], ascending=False)
)

# %%
ggplot(
    cart_model_coeffs_var_imp_df.iloc[:10, :],
    aes(x='reorder(varname, imp)', y='imp_percentage'),
) + geom_point(color=color[0], size=1.5) + geom_segment(
    aes(x='varname', xend='varname', y=0, yend='imp_percentage'), color=color[0], size=1
) + ylab(
    'Importance (Percent)'
) + xlab(
    'cart Model Variable Name'
) + coord_flip() + scale_y_continuous(
    labels=percent_format()
) + theme_bw()
# Out:
# <ggplot: (8774988613585)>

# %%
# cross validation
cart_model = DecisionTreeRegressor()
cart_cv_mse = cross_val_score(cart_model, X_std, y, cv=5, scoring='neg_mean_squared_error')
cart_cv_rmse = [np.sqrt(-x) for x in cart_cv_mse]

# %%
cart_cv_rmse
# Out:
# [48.51049101878513,
#  41.44649238856097,
#  42.082834924344525,
#  42.63813324726742,
#  45.00636452416612]

# %% [markdown]
# ### GBM Model

# %%
gbm_model = GradientBoostingRegressor().fit(X_train, y_train)
y_hat = gbm_model.predict(X_test)
gbm_rmse = mean_squared_error(y_test, y_hat, squared=False)

# %%
gbm_model_coeffs_df = pd.DataFrame(
    gbm_model.feature_importances_.tolist(),
    index=X.columns,
    columns=['gbm_coefficient'],
).assign(gbm_coefficient=lambda x: x.gbm_coefficient.round(3))
gbm_model_coeffs_df.sort_values('gbm_coefficient', inplace=True, ascending=False)

# %%
gbm_model_coeffs_df.plot.bar(y='gbm_coefficient', rot=90, figsize=(15, 5), title='gbm Model Coeffs')
# Out:
# <AxesSubplot:title={'center':'gbm Model Coeffs'}>

# %%
for index in gbm_model_coeffs_df.index:
    print(index, gbm_model_coeffs_df.loc[index].values[0])
# Out:
# n_accommodates 0.398
# f_room_type 0.192
# n_bathrooms 0.147
# d_Dishwasher 0.029
# n_beds 0.027
# n_minimum_nights 0.025
# n_reviews_per_month 0.024
# d_Elevator 0.019
# d_Paid parking off premises 0.016
# d_Dryer 0.011
# ln_days_since 0.011
# d_Coffee maker 0.01
# n_review_scores_rating 0.009
# d_Fire extinguisher 0.009
# d_High chair 0.008
# d_Free street parking 0.007
# n_days_since 0.007
# ln_number_of_reviews 0.006
# n_number_of_reviews 0.005
# d_Cable TV 0.004
# d_TV 0.004
# d_Baking sheet 0.004
# d_Iron 0.004
# d_Shampoo 0.004
# d_Shower gel 0.003
# d_Microwave 0.003
# d_Hair dryer 0.002
# d_Host greets you 0.002
# d_Hot water 0.001
# d_Long term stays allowed 0.001
# d_Hot water kettle 0.001
# d_Washer 0.001
# d_Heating 0.001
# d_TV with standard cable 0.001
# d_Private entrance 0.001
# d_Carbon monoxide alarm 0.001
# d_Patio or balcony 0.001
# d_Luggage dropoff allowed 0.001
# d_Dining table 0.0
# d_Dishes and silverware 0.0
# f_number_of_reviews 0.0
# d_Kitchen 0.0
# d_Wifi 0.0
# d_Essentials 0.0
# d_Cooking basics 0.0
# d_Smoke alarm 0.0
# d_Refrigerator 0.0
# d_Stove 0.0
# d_Oven 0.0
# d_Backyard 0.0
# d_Cleaning products 0.0
# d_Freezer 0.0
# d_Bed linens 0.0
# d_Dedicated workspace 0.0
# d_Single level home 0.0
# d_Room-darkening shades 0.0
# d_Free parking on premises 0.0
# d_Hangers 0.0
# d_Lock on bedroom door 0.0
# d_Extra pillows and blankets 0.0
# d_First aid kit 0.0
# d_Bathtub 0.0

# %%
gbm_model_coeffs_var_imp_df = (
    pd.DataFrame(
        abs(gbm_model.feature_importances_), X.columns
    )
    .reset_index()
    .rename({'index': 'varname',0: 'imp'}, axis=1)
    .assign(imp_percentage=lambda x: x['imp'] / x['imp'].sum())
    .sort_values(by=['imp'], ascending=False)
)

# %%
ggplot(
    gbm_model_coeffs_var_imp_df.iloc[:10, :],
    aes(x='reorder(varname, imp)', y='imp_percentage'),
) + geom_point(color=color[0], size=1.5) + geom_segment(
    aes(x='varname', xend='varname', y=0, yend='imp_percentage'), color=color[0], size=1
) + ylab(
    'Importance (Percent)'
) + xlab(
    'gbm Model Variable Name'
) + coord_flip() + scale_y_continuous(
    labels=percent_format()
) + theme_bw()
# Out:
# <ggplot: (8774955106081)>

# %%
# cross validation
gbm_model = GradientBoostingRegressor()
gbm_cv_mse = cross_val_score(gbm_model, X_std, y, cv=5, scoring='neg_mean_squared_error')
gbm_cv_rmse = [np.sqrt(-x) for x in gbm_cv_mse]

# %%
gbm_cv_rmse
# Out:
# [28.48379422322291,
#  31.12546589850167,
#  28.587364722779995,
#  30.246586609679316,
#  30.27219050943554]

# %%
def combine(type_, rmse):
    res = []
    index = 1
    for r in rmse:
        res.append([index, type_, r])
        index += 1
    return res

# %%
# cv RMSE compare
plt.figure(figsize=(10, 6))
plt.xlabel('No.', fontsize=12)
plt.ylabel('RMSE', fontsize=12)
ax = plt.gca()
ax.tick_params(axis='both', which='both', direction='in')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
serial = [1, 2, 3, 4, 5]
plt.plot(serial, ols_cv_rmse, 'r-*', label='OLS')
plt.plot(serial, lasso_cv_rmse, 'b-o', label='Lasso')
plt.plot(serial, cart_cv_rmse, 'g--^', label='CART')
plt.plot(serial, gbm_cv_rmse, 'k-->', label='GBM')
plt.title('RMSE of Four Models on Test Dataset')
plt.xticks(serial)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
x_list = ['OLS', 'Lasso', 'CART', 'GBM']
y_list = [round(np.mean(ols_cv_rmse), 3), 
          round(np.mean(lasso_cv_rmse), 3), 
          round(np.mean(cart_cv_rmse), 3), 
          round(np.mean(gbm_cv_rmse), 3)]
plt.bar(x_list, y_list)
plt.title('Mean CV RMSE of Four Models')
plt.ylabel('RMSE')
plt.ylim([25, 49])
for a, b in zip(x_list, y_list):
    plt.text(a, b, b, ha='center', va='bottom', fontsize=12)
plt.show()

# %% [markdown]
# ## GBM is the best
